# %%
from preprocessing_GAN import *
# Out:
# /home/jupyter-zhw622/DeepLearning/preprocessing.py:41: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   train_data = torch.tensor(train_data)

# %%
print(train_data.shape)
# Out:
# torch.Size([280, 1, 1, 64, 64])

# %%
for i in range(10):
    print("training images for person ", i, ": ")
    label_to_picture(i)
    print("attact result for person ", i, ": ")
    generated_image(i)
# Out:
# training images for person  0 :
# attact result for person  0 :
# training images for person  1 :
# attact result for person  1 :
# training images for person  2 :
# attact result for person  2 :
# training images for person  3 :
# attact result for person  3 :
# training images for person  4 :
# attact result for person  4 :
# training images for person  5 :
# attact result for person  5 :
# training images for person  6 :
# attact result for person  6 :
# training images for person  7 :
# attact result for person  7 :
# training images for person  8 :
# attact result for person  8 :
# training images for person  9 :
# attact result for person  9 :

# %%
import torch_dct as dct

# %%
for i in range(280):
    train_data[i] = dct.idct_2d(train_data[i])
    # train_data[i] = dct.idct_2d(imf)

# %%
for i in range(10):
    print("training images for person ", i, ": ")
    label_to_picture(i)
    print("attact result for person ", i, ": ")
    generated_image(i)
# Out:
# training images for person  0 :
# attact result for person  0 :
# training images for person  1 :
# attact result for person  1 :
# training images for person  2 :
# attact result for person  2 :
# training images for person  3 :
# attact result for person  3 :
# training images for person  4 :
# attact result for person  4 :
# training images for person  5 :
# attact result for person  5 :
# training images for person  6 :
# attact result for person  6 :
# training images for person  7 :
# attact result for person  7 :
# training images for person  8 :
# attact result for person  8 :
# training images for person  9 :
# attact result for person  9 :
